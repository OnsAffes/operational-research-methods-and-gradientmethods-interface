# %%
############# interface de l'application #############
import import_ipynb
from tkinter import * 
import tkinter as tk
import projet4
import projet1
import projet2
import projet5
import projet6
from tkinter import messagebox

#initialisation
f1=1
f2=1
f3=1
f4=1
f5=1
f6=1
f7=1
f8=1
f9=1
f10=1
f11=1
f12=1
f13=1
f71=1
f91=1
f92=1

#Controle de saisie et récupération de la fonction saisie dans les projets 1,2 et 4
fonct=""
global fonct   
def stokfonct():
    fonct=entryfn.get()
    return(fonct)

def controlFonct():
    fonct=stokfonct()
    if fonct=='':
        messagebox.showinfo('warning', 'Le champs est vide !')
        closef10()
        openf10()
        
    
#Controle de saisie et récupération du Mode dans le projet 6
m=""
global m    
def stok():
    m=entryM.get()
    if m.isdigit() == False:
        messagebox.showinfo('warning', 'Veuillez entrer un nombre !')
    elif int(m)<1 or int(m)>2:
         messagebox.showinfo('warning', 'Veuillez entrer un mode soit 1 soit 2 !')
         closef11()
         openf11()
    return(m)
    
    
#récupération du nombre de contraintes dans les projets 5 et 6 
c=""
global c    
def stokC():
    c=entryC.get()
    return(c)
        
    
#récupération du coefficient de x1 dans Z dans les projets 5 et 6 dans R
z=""
global z    
def stokZ():
    z=entryZ.get()
    return(z)
#récupération du coefficient de x2 dans Z dans les projets 5 et 6 dans R
z1=""
global z1    
def stokZ1():
    z1=entryZ1.get()
    return(z1)


######### CONTROLE DE SAISIE sur les champs vides #############
def controlSaisie():
    m=stok()
    c=stokC()
    z=stokZ()
    z1=stokZ1()
    if m=='' or c==''or z=='' or z1=='':
        messagebox.showinfo('warning', 'Il y a des champs vide !')
        closef11()
        openf11()
        
global input_text
input_text=''
def get_value():
    input_text=entryfn.get()
    return(input_text)
    
    
#récupération du nombre de contraintes dans les projets 5 et 6 
c=""
global c    
def stokC():
    c=entryC.get()
    return(c)
        
#récupération du coefficient de x1 dans Z dans les projets 5 et 6 dans R
z=""
global z    
def stokZ():
    z=entryZ.get()
    return(z)

#récupération du coefficient de x2 dans Z dans les projets 5 et 6 dans R
z1=""
global z1    
def stokZ1():
    z1=entryZ1.get()
    return(z1)

    
def btn_clicked():

    print("Button Clicked")
#fonctions pour la fermeture des fenetres
def closef1():
    f1.destroy()
def closef2():
    f2.destroy()
def closef3():
    f3.destroy()
def closef4():
    f4.destroy()
def closef5():
    f5.destroy()
def closef6():
    f6.destroy()
def closef7():
    f7.destroy()
def closef8():
    f8.destroy()
def closef9():
    f9.destroy()
def closef10():
    f10.destroy()
def closef11():
    f11.destroy()
def closef12():
    f12.destroy()
def closef13():
    f13.destroy()
def closef71():
    f71.destroy()
def closef91():
    f91.destroy()

    
#Tous ces fonctions permettent de passer d'une fenetre à une autre
def menu2():
    f1.destroy() #fermer la fenetre f1
    openf2() # ouvrir la fenetre f2
def menu3():
    f2.destroy()
    openf3()
def menu4():
    f2.destroy()
    openf4()
def menu5():
    f3.destroy()
    openf5()
def menu6():
    f4.destroy()
    openf6()
def menu7():
    f5.destroy()
    openf7()
def menu8():
    f4.destroy()
    openf8()
def menu9():
    f6.destroy()
    openf9()
def menu10():
    f3.destroy()
    openf10()
def menu11():
    f10.destroy()
    openf7()
def menu12():
    f4.destroy()
    openf11()
def menu13():
    f11.destroy()
    openf12()
def menu13():
    f4.destroy()
    openf13()
def menu71():
    f10.destroy()
    openf7_1()
def menu91():
    f11.destroy()
    openf9_1()
def menu92():
    f13.destroy()
    openf9_2()
# Tous ces fonctions permettent de retourner d'une fenetre à une autre
def retour():
    f2.destroy() #fermer f2
    openf1() #ouvrir f1
def retour1():
    f3.destroy()
    openf2()
def retour2():
    f4.destroy()
    openf2()
def retour3():
    f5.destroy()
    openf3()
def retour4():
    f6.destroy()
    openf4()
def retour5():
    f7.destroy()
    openf5()
def retour6():
    f8.destroy()
    openf4()
def retour7():
    f9.destroy()
    openf6()
def retour8():
    f10.destroy()
    openf3()
def retour9():
    f11.destroy()
    openf4()
def retour10():
    f7.destroy()
    openf10()
def retour11():
    f12.destroy()
    openf11()
def retour12():
    f13.destroy()
    openf4()
def retour71():
    f71.destroy()
    openf10()
def retour91():
    f91.destroy()
    openf11()
def retour92():
    f92.destroy()
    openf13()
    
#inerface d'acceuil
def openf1():
    global f1
    f1 = Tk() #Pour ouvrir une nouvelle fenetre 
    f1.geometry("1000x600") #dimension de la fenetre 
    f1.configure(bg = "#f5f5f5") #backgroundColor
    canvas = Canvas(
        f1,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0) 

    img0 = PhotoImage(file = f"img0.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = menu2,
        relief = "flat")
   #placement de la bouton dans la fenetre
    b0.place(
        x = 597, y = 342,
        width = 424,
        height = 151)

    img1 = PhotoImage(file = f"img1.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef1,

        relief = "flat")
 #placement de la bouton dans la fenetre
    b1.place(
        x = 686, y = 453,
        width = 283,
        height = 104)
    
    img2 = PhotoImage(file = f"img2.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command = btn_clicked,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 138, y = 13,
        width = 770,
        height = 124)

    background_img = PhotoImage(file = f"background.png")
    background = canvas.create_image(
        340.5, 374.0,
        image=background_img)

    f1.resizable(False, False)
    f1.mainloop()
#interface pour choisir les méthode de gradients ou recherche opérationnelle
def openf2():
    global f2
    f2 = Tk() #Pour ouvrir une nouvelle fenetre
    f2.geometry("1000x600")
    f2.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f2,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    img0 = PhotoImage(file = f"img3.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = menu3,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 139, y = 231,
        width = 306,
        height = 235)

    img1 = PhotoImage(file = f"img4.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = menu4,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 520, y = 231,
        width = 306,
        height = 235)

    img2 = PhotoImage(file = f"img1.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef2,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 684, y = 477,
        width = 283,
        height = 104)

    img3 = PhotoImage(file = f"img5.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour,
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 0, y = 0,
        width = 108,
        height = 74)

    canvas.create_text(
        260.5, 173.5,
        text = "Veuillez choisir une methode:  ",
        fill = "#746a6a",
        font = ("None", int(22.0)))

    f2.resizable(False, False)
    f2.mainloop()
#interface pour choisir une fonction de la mémoire ou la saisir manuellement
def openf3():
    global f3
    f3 = Tk() #Pour ouvrir une nouvelle fenetre

    f3.geometry("1000x600")
    f3.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f3,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background2.png")
    background = canvas.create_image(
        771.0, 367.5,
        image=background_img)

    img0 = PhotoImage(file = f"img6.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur choisir une fonction de la mémoire , ces fonctions seront déclenchés
        command=lambda:[projet4.myfunction('choisir'),projet1.myfunction('choisir'),projet2.myfunction('choisir'),menu5()],
        relief = "flat")
    #placement de la bouton dans la fenetre
    b0.place(
        x = 28, y = 135,
        width = 514,
        height = 131)

    img1 = PhotoImage(file = f"img5.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour1,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 2, y = 0,
        width = 108,
        height = 74)

    img2 = PhotoImage(file = f"img7.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur saisir votre propre fonction , ces fonctions seront déclenchés
        command=lambda:[projet4.myfunction('saisir'),projet1.myfunction('saisir'),projet2.myfunction('saisir'),menu10()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 28, y = 249,
        width = 514,
        height = 131)

    img3 = PhotoImage(file = f"img1.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef3,
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 83, y = 380,
        width = 283,
        height = 104)

    f3.resizable(False, False)
    f3.mainloop()
#interface pour choisir un Pl de la mémoire ou le saisir manuellement dans R ou dans Rn
def openf4():
    global f4
    f4 = Tk() #Pour ouvrir une nouvelle fenetre
 

    f4.geometry("1000x600")
    f4.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f4,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background2.png")
    background = canvas.create_image(
        771.0, 367.5,
        image=background_img)

    img0 = PhotoImage(file = f"img8.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur choisir un PL  ded la mémoire , ces fonctions seront déclenchés
        command=lambda:[projet6.myfunction1(1),projet5.myfunction(1),menu6()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 41, y = 62,
        width = 514,
        height = 120)

    img1 = PhotoImage(file = f"img5.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour2,
        relief = "flat")

    b1.place(
        x = 2, y = 0,
        width = 108,
        height = 74)

    img2 = PhotoImage(file = f"img9.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur saisir votre propre PL dans R , ces fonctions seront déclenchés
        command = lambda:[projet6.myfunction1(2),projet5.myfunction(2),menu12()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 28, y = 182,
        width = 514,
        height = 119)

    img3 = PhotoImage(file = f"img10.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur saisir votre propre PL dans Rn , ces fonctions seront déclenchés
        command = lambda:[projet6.myfunction1(3),projet5.myfunction(3),menu13()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 28, y = 296,
        width = 514,
        height = 119)

    img4 = PhotoImage(file = f"img1.png")
    b4 = Button(
        image = img4,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef4,
        relief = "flat")
#placement de la bouton dans la fenetre
    b4.place(
        x = 96, y = 421,
        width = 283,
        height = 104)

    f4.resizable(False, False)
    f4.mainloop()
#interface pour choisir une fonction de la mémoire
def openf5():
    global f5 
    f5 = Tk() #Pour ouvrir une nouvelle fenetre
    f5.title('Choisir fonction')
    f5.geometry("1000x600")
    f5.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f5,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background3.png")
    background = canvas.create_image(
        730.5, 328.0,
        image=background_img)

    img0 = PhotoImage(file = f"img11.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur la 1ére fonction de la mémoire , ces fonctions seront déclenchés
        command=lambda:[projet4.myfunction2('(1 − 𝑥)² + 100(𝑦 − 𝑥²)²'),projet1.myfunction2('(1 − 𝑥)² + 100(𝑦 − 𝑥²)²'),projet2.myfunction2('(1 − 𝑥)² + 100(𝑦 − 𝑥²)²'),menu7()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 70, y = 188,
        width = 361,
        height = 69)

    img1 = PhotoImage(file = f"img12.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur la 3éme fonction de la mémoire , ces fonctions seront déclenchés
        command=lambda:[projet4.myfunction2('1/2 <Ax,x>-<b,x>'),projet1.myfunction2('1/2 <Ax,x>-<b,x>'),projet2.myfunction2('1/2 <Ax,x>-<b,x>'),menu7()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 74, y = 350,
        width = 367,
        height = 168)

    img2 = PhotoImage(file = f"img13.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur la 2éme fonction de la mémoire , ces fonctions seront déclenchés
        command = lambda:[projet4.myfunction2('xexp(-x²-y²)'),projet1.myfunction2('xexp(-x²-y²)'),projet2.myfunction2('xexp(-x²-y²)'),menu7()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 73, y = 269,
        width = 367,
        height = 81)

    img3 = PhotoImage(file = f"img5.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour3,
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 2, y = 0,
        width = 108,
        height = 74)

    img4 = PhotoImage(file = f"img1.png")
    b4 = Button(
        image = img4,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef5,
        relief = "flat")
#placement de la bouton dans la fenetre
    b4.place(
        x = 702, y = 496,
        width = 283,
        height = 104)

    canvas.create_text(
        279.0, 142.5,
        text = "Veuillez choisir une fonction de la memoire :",
        fill = "#000000",
        font = ("None", int(19.0)))

    f5.resizable(False, False)
    f5.mainloop()
#interface pour choisir un PL de la mémoire
def openf6():
    global f6
    f6 = Tk() #Pour ouvrir une nouvelle fenetre

    f6.geometry("1000x600")
    f6.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f6,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    img0 = PhotoImage(file = f"img14.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
          #En cliquant sur le PL1 , ces fonctions seront déclenchés
        command=lambda:[projet6.myfunction(1),projet5.myfunction1(1),menu9()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 70, y = 182,
        width = 248,
        height = 285)

    img1 = PhotoImage(file = f"img15.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
          #En cliquant sur le PL2 , ces fonctions seront déclenchés
        command=lambda:[projet6.myfunction(2),projet5.myfunction1(2),menu9()],
        relief = "flat")

    b1.place(
        x = 376, y = 182,
        width = 248,
        height = 285)

    img2 = PhotoImage(file = f"img16.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur le PL3 , ces fonctions seront déclenchés
        command=lambda:[projet6.myfunction(3),projet5.myfunction1(3),menu9()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 694, y = 182,
        width = 248,
        height = 285)

    img3 = PhotoImage(file = f"img5.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour4,
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 2, y = 0,
        width = 108,
        height = 74)

    img4 = PhotoImage(file = f"img1.png")
    b4 = Button(
        image = img4,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef6,
        relief = "flat")
#placement de la bouton dans la fenetre
    b4.place(
        x = 702, y = 496,
        width = 283,
        height = 104)

    canvas.create_text(
        288.0, 110.5,
        text = "Veuillez choisir un PL de la memoire :",
        fill = "#000000",
        font = ("None", int(19.0)))

    f6.resizable(False, False)
    f6.mainloop()
#interface pour choisir une méthode de gradient à appliquer aprés avoir choisi une foncion de la mémoire
def openf7():
    global f7
    f7 = Tk() #Pour ouvrir une nouvelle fenetre
    f7.geometry("1000x600")
    f7.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f7,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background4.png")
    background = canvas.create_image(
        199.5, 399.0,
        image=background_img)

    img0 = PhotoImage(file = f"img5.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour5,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 0, y = 0,
        width = 108,
        height = 74)

    img1 = PhotoImage(file = f"img1.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef7,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 693, y = 483,
        width = 283,
        height = 104)

    img2 = PhotoImage(file = f"img17.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur le bouton méthode de gradient, le menu principal du projet1 va etre déclenché
        command = projet1.menu,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 453, y = 124,
        width = 522,
        height = 85)

    img3 = PhotoImage(file = f"img18.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur le bouton méthode de gradient conjugé avec la régla d'Armijo, le menu principal du projet2 va etre déclenché
        command = projet2.menu1,
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 419, y = 220,
        width = 581,
        height = 95)

    img4 = PhotoImage(file = f"img19.png")
    b4 = Button(
        image = img4,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur le bouton méthode de gradient conjugé standard, le menu principal du projet4 va etre déclenché
        command = projet4.menu,
        relief = "flat")
#placement de la bouton dans la fenetre
    b4.place(
        x = 453, y = 326,
        width = 519,
        height = 90)

    f7.resizable(False, False)
    f7.mainloop()
#interface pour choisir une méthode de gradient à appliquer aprés avoir saisi une fonction manuellement
def openf7_1():
    global f71
    f71 = Tk() #Pour ouvrir une nouvelle fenetre

    f71.geometry("1000x600")
    f71.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f71,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background4.png")
    background = canvas.create_image(
        199.5, 399.0,
        image=background_img)

    img0 = PhotoImage(file = f"img5.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour71,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 0, y = 0,
        width = 108,
        height = 74)

    img1 = PhotoImage(file = f"img1.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef71,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 693, y = 483,
        width = 283,
        height = 104)

    img2 = PhotoImage(file = f"img17.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur le bouton méthode de gradient, le menu principal du projet1 va etre déclenché
        command = projet1.menu,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 453, y = 124,
        width = 522,
        height = 85)

    img3 = PhotoImage(file = f"img18.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        command = projet2.menu1,
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 419, y = 220,
        width = 581,
        height = 95)

    img4 = PhotoImage(file = f"img19.png")
    b4 = Button(
        image = img4,
        borderwidth = 0,
        highlightthickness = 0,
        #En cliquant sur le bouton méthode de gradient conjugé standard, le menu principal du projet4 va etre déclenché
        command = projet4.menu,
        relief = "flat")
#placement de la bouton dans la fenetre
    b4.place(
        x = 453, y = 326,
        width = 519,
        height = 90)

    f71.resizable(False, False)
    f71.mainloop()
    
def openf8():
    global f8
    f8 = Tk() #Pour ouvrir une nouvelle fenetre
    f8.geometry("1000x600")
    f8.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f8,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background3.png")
    background = canvas.create_image(
        199.5, 399.0,
        image=background_img)

    img0 = PhotoImage(file = f"img5.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour6,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 0, y = 0,
        width = 108,
        height = 74)

    img1 = PhotoImage(file = f"img1.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef8,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 693, y = 483,
        width = 283,
        height = 104)

    canvas.create_text(
        238.0, 164.0,
        text = "Veuillez choisir une methode :",
        fill = "#312f2f",
        font = ("Inter-SemiBold", int(20.0)))

    img2 = PhotoImage(file = f"img20.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command = btn_clicked,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 543, y = 217,
        width = 259,
        height = 58)

    img3 = PhotoImage(file = f"img21.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        command = btn_clicked,
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 543, y = 300,
        width = 259,
        height = 58)

    f8.resizable(False, False)
    f8.mainloop()
#choisir une méthode à appliquer aprés avoir choisi un PL de la mémoire
def openf9():
    global f9
    f9 = Tk() #Pour ouvrir une nouvelle fenetre

    f9.geometry("1000x600")
    f9.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f9,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background5.png")
    background = canvas.create_image(
        199.5, 405.0,
        image=background_img)

    img0 = PhotoImage(file = f"img5.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour7,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 0, y = 6,
        width = 108,
        height = 74)

    img1 = PhotoImage(file = f"img1.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef9,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 693, y = 489,
        width = 283,
        height = 104)

    canvas.create_text(
        238.0, 170.0,
        text = "Veuillez choisir une methode :",
        fill = "#312f2f",
        font = ("Inter-SemiBold", int(20.0)))

    img2 = PhotoImage(file = f"img22.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command=projet5.menu, #######
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 545, y = 222,
        width = 259,
        height = 59)

    img3 = PhotoImage(file = f"img23.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
         #losqu'on clique sur le bouton BIG M le menu du projet 6 va etre déclenché
        command=lambda:[projet6.menu_principale(1,0,[],[],0,0,0,[],[],[],[],[],[],[],[],0,[],[],-1)],
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 543, y = 314,
        width = 261,
        height = 58)

    f9.resizable(False, False)
    f9.mainloop()
#choisir une méthode à appliquer aprés avoir saisi un PL manulellement dans R
def openf9_1():
    global f91
    f91 = Tk() #Pour ouvrir une nouvelle fenetre

    f91.geometry("1000x600")
    f91.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f91,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background5.png")
    background = canvas.create_image(
        199.5, 405.0,
        image=background_img)

    img0 = PhotoImage(file = f"img5.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour91,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 0, y = 6,
        width = 108,
        height = 74)

    img1 = PhotoImage(file = f"img1.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef91,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 693, y = 489,
        width = 283,
        height = 104)

    canvas.create_text(
        238.0, 170.0,
        text = "Veuillez choisir une methode :",
        fill = "#312f2f",
        font = ("Inter-SemiBold", int(20.0)))

    img2 = PhotoImage(file = f"img22.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command=projet5.menu,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 545, y = 222,
        width = 259,
        height = 59)

    img3 = PhotoImage(file = f"img23.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
         #losqu'on clique sur le bouton BIG le menu principal du projet 6 va etre déclenché 
        command=lambda:[projet6.menu_principale(1,0,[],[],m,c,2,[],[],[],[],[],[],[],[],0,[],[],-1)],
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 543, y = 314,
        width = 261,
        height = 58)

    f91.resizable(False, False)
    f91.mainloop()
#choisir une méthode à appliquer aprés avoir saisi un PL manulellement dans Rn
def openf9_2():
    global f92
    f92 = Tk() #Pour ouvrir une nouvelle fenetre
    f92.geometry("1000x600")
    f92.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f92,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background5.png")
    background = canvas.create_image(
        199.5, 405.0,
        image=background_img)

    img0 = PhotoImage(file = f"img5.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour92,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 0, y = 6,
        width = 108,
        height = 74)

    img1 = PhotoImage(file = f"img1.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef91,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 693, y = 489,
        width = 283,
        height = 104)

    canvas.create_text(
        238.0, 170.0,
        text = "Veuillez choisir une methode :",
        fill = "#312f2f",
        font = ("Inter-SemiBold", int(20.0)))

    img2 = PhotoImage(file = f"img22.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        #losqu'on clique sur le bouton SIMPLEXE le menu du projet 5 va etre déclenché
        command=projet5.menu,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 545, y = 222,
        width = 259,
        height = 59)

    img3 = PhotoImage(file = f"img23.png")
    b3 = Button(
        image = img3,
        borderwidth = 0,
        highlightthickness = 0,
        #losqu'on clique sur le bouton BIG M le menu du projet 6 va etre déclenché
        command=lambda:[projet6.menu_principale(1,0,[],[],0,0,0,[],[],[],[],[],[],[],[],0,[],[],-1)],
        relief = "flat")
#placement de la bouton dans la fenetre
    b3.place(
        x = 543, y = 314,
        width = 261,
        height = 58)

    f92.resizable(False, False)
    f92.mainloop()
#interface pour la saisie de la fonction par l'utilisateur
def openf10():
    global f10
    global entryfn
    f10 = Tk() #Pour ouvrir une nouvelle fenetre
    f10.title('saisir fonction')
    f10.geometry("1000x600")
    f10.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f10,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background6.png")
    background = canvas.create_image(
        182.5, 414.0,
        image=background_img)

    img0 = PhotoImage(file = f"img25.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        #losqu'on clique sur suivant tous ces fonctions s'éxecutent
        command=lambda:[controlFonct(),projet4.functionsaisie(get_value()),projet1.functionsaisie(get_value()),projet2.functionsaisie(get_value()),menu71()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 796, y = 512,
        width = 165,
        height = 77)

    img1 = PhotoImage(file = f"img26.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef10,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 638, y = 512,
        width = 165,
        height = 77)

    canvas.create_text(
        501.5, 74.0,
        text = "Saisir votre propre fonction",
        fill = "#bb90cf",
        font = ("Inter-Regular", int(30.0)))

    canvas.create_text(
        645.5, 260.0,
        text = "Donner une fonction de votre choix",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    entry0_img = PhotoImage(file = f"img_textBox4.png")
    entry0_bg = canvas.create_image(
        648.0, 303.5,
        image = entry0_img)

    entryfn = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entryfn.place(
        x = 479, y = 289,
        width = 338,
        height = 27)

    img2 = PhotoImage(file = f"img5.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour8,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 0, y = 0,
        width = 108,
        height = 74)

    f10.resizable(False, False)
    f10.mainloop()
#interface pour la saisie d'un PL dans R
def openf11():
    global f11
    f11 = Tk() #Pour ouvrir une nouvelle fenetre
    global entryM
    global entryC
    global entryZ
    global entryZ1

    f11.geometry("1000x600")
    f11.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f11,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background6.png")
    background = canvas.create_image(
        182.5, 414.0,
        image=background_img)

    img0 = PhotoImage(file = f"img25.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        #losqu'on clique sur suivant tous ces fonctions s'éxecutent
        command = lambda:[controlSaisie(),projet6.fn(stok()),projet6.fnC(stokC()),projet6.fnZ(stokZ()),projet6.fnZ1(stokZ1()),projet5.fnC(stokC()),projet5.fnZ(stokZ()),projet5.fnZ1(stokZ1()),projet5.fnZ(stokZ()),menu91()],
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 796, y = 512,
        width = 165,
        height = 77)

    img1 = PhotoImage(file = f"img26.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef11,
        relief = "flat")
#placement de la bouton dans la fenetre
    b1.place(
        x = 638, y = 512,
        width = 165,
        height = 77)

    canvas.create_text(
        448.5, 72.0,
        text = "Saisir un PL dans R",
        fill = "#bb90cf",
        font = ("Inter-Regular", int(30.0)))

    canvas.create_text(
        592.5, 150.0,
        text = "Choisir un mode: 1)Max  2)Min",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    canvas.create_text(
        604.5, 249.0,
        text = "Donner le nombre de contraintes",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    entry0_img = PhotoImage(file = f"img_textBox0.png")
    entry0_bg = canvas.create_image(
        618.0, 190.0,
        image = entry0_img)
#zone de texte pour le mode 
    entryM = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entryM.place(
        x = 449, y = 175,
        width = 338,
        height = 28)

    entry1_img = PhotoImage(file = f"img_textBox1.png")
    entry1_bg = canvas.create_image(
        618.0, 284.5,
        image = entry1_img)
#zone de texte pour le nombre de containtes
    entryC = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entryC.place(
        x = 449, y = 270,
        width = 338,
        height = 27)

    canvas.create_text(
        596.5, 334.0,
        text = "Donner le coefficient X1 dans Z",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    entry2_img = PhotoImage(file = f"img_textBox2.png")
    entry2_bg = canvas.create_image(
        618.0, 374.5,
        image = entry2_img)
#zone de texte pour le coefficient de x1 de z 
    entryZ = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entryZ.place(
        x = 449, y = 360,
        width = 338,
        height = 27)

    canvas.create_text(
        598.0, 431.0,
        text = "Donner le coefficient X2 dans Z",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    entry3_img = PhotoImage(file = f"img_textBox3.png")
    entry3_bg = canvas.create_image(
        618.0, 471.5,
        image = entry3_img)
#zone de texte pour le coefficient de x2 de z 
    entryZ1 = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entryZ1.place(
        x = 449, y = 457,
        width = 338,
        height = 27)

    img2 = PhotoImage(file = f"img5.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour9,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 0, y = 0,
        width = 108,
        height = 74)

    f11.resizable(False, False)
    f11.mainloop()
    
# def openf12():
#     global f12
#     f12 = Tk()

#     f12.geometry("1000x600")
#     f12.configure(bg = "#f5f5f5")
#     canvas = Canvas(
#         f12,
#         bg = "#f5f5f5",
#         height = 600,
#         width = 1000,
#         bd = 0,
#         highlightthickness = 0,
#         relief = "ridge")
#     canvas.place(x = 0, y = 0)

#     background_img = PhotoImage(file = f"background6.png")
#     background = canvas.create_image(
#         182.5, 414.0,
#         image=background_img)

#     img0 = PhotoImage(file = f"img25.png")
#     b0 = Button(
#         image = img0,
#         borderwidth = 0,
#         highlightthickness = 0,
#         command = btn_clicked,
#         relief = "flat")

#     b0.place(
#         x = 796, y = 512,
#         width = 165,
#         height = 77)

#     img1 = PhotoImage(file = f"img26.png")
#     b1 = Button(
#         image = img1,
#         borderwidth = 0,
#         highlightthickness = 0,
#         command = closef12,
#         relief = "flat")

#     b1.place(
#         x = 638, y = 512,
#         width = 165,
#         height = 77)

#     canvas.create_text(
#         448.5, 72.0,
#         text = "Saisir un PL dans R",
#         fill = "#bb90cf",
#         font = ("Inter-Regular", int(30.0)))

#     canvas.create_text(
#         632.0, 149.0,
#         text = "Choisir le type de contrainte (=<|=|>=) ",
#         fill = "#726d72",
#         font = ("Inter-Regular", int(20.0)))

#     canvas.create_text(
#         649.0, 249.0,
#         text = "Donner le coefficient X1 dans la contrainte",
#         fill = "#726d72",
#         font = ("Inter-Regular", int(20.0)))

#     entry0_img = PhotoImage(file = f"img_textBox5.png")
#     entry0_bg = canvas.create_image(
#         618.0, 190.0,
#         image = entry0_img)

#     entry0 = Entry(
#         bd = 0,
#         bg = "#ffffff",
#         highlightthickness = 0)

#     entry0.place(
#         x = 449, y = 175,
#         width = 338,
#         height = 28)

#     entry1_img = PhotoImage(file = f"img_textBox6.png")
#     entry1_bg = canvas.create_image(
#         618.0, 284.5,
#         image = entry1_img)

#     entry1 = Entry(
#         bd = 0,
#         bg = "#ffffff",
#         highlightthickness = 0)

#     entry1.place(
#         x = 449, y = 270,
#         width = 338,
#         height = 27)

#     canvas.create_text(
#         650.5, 334.0,
#         text = "Donner le coefficient X2 dans la contrainte",
#         fill = "#726d72",
#         font = ("Inter-Regular", int(20.0)))

#     entry2_img = PhotoImage(file = f"img_textBox7.png")
#     entry2_bg = canvas.create_image(
#         618.0, 374.5,
#         image = entry2_img)

#     entry2 = Entry(
#         bd = 0,
#         bg = "#ffffff",
#         highlightthickness = 0)

#     entry2.place(
#         x = 449, y = 360,
#         width = 338,
#         height = 27)

#     canvas.create_text(
#         605.0, 431.0,
#         text = "Donner le RHS dans la contrainte",
#         fill = "#726d72",
#         font = ("Inter-Regular", int(20.0)))

#     entry3_img = PhotoImage(file = f"img_textBox8.png")
#     entry3_bg = canvas.create_image(
#         618.0, 471.5,
#         image = entry3_img)

#     entry3 = Entry(
#         bd = 0,
#         bg = "#ffffff",
#         highlightthickness = 0)

#     entry3.place(
#         x = 449, y = 457,
#         width = 338,
#         height = 27)

#     img2 = PhotoImage(file = f"img5.png")
#     b2 = Button(
#         image = img2,
#         borderwidth = 0,
#         highlightthickness = 0,
#         command = retour11,
#         relief = "flat")

#     b2.place(
#         x = 0, y = -2,
#         width = 108,
#         height = 74)

#     f12.resizable(False, False)
#     f12.mainloop()


#interface pour la saisie d'un PL dans Rn
def openf13():
    global f13
    f13 = Tk() #Pour ouvrir une nouvelle fenetre

    f13.geometry("1000x600")
    f13.configure(bg = "#f5f5f5")
    canvas = Canvas(
        f13,
        bg = "#f5f5f5",
        height = 600,
        width = 1000,
        bd = 0,
        highlightthickness = 0,
        relief = "ridge")
    canvas.place(x = 0, y = 0)

    background_img = PhotoImage(file = f"background6.png")
    background = canvas.create_image(
        182.5, 414.0,
        image=background_img)

    img0 = PhotoImage(file = f"img25.png")
    b0 = Button(
        image = img0,
        borderwidth = 0,
        highlightthickness = 0,
        command = menu92,
        relief = "flat")
#placement de la bouton dans la fenetre
    b0.place(
        x = 796, y = 512,
        width = 165,
        height = 77)

    img1 = PhotoImage(file = f"img26.png")
    b1 = Button(
        image = img1,
        borderwidth = 0,
        highlightthickness = 0,
        command = closef13,
        relief = "flat")

    b1.place(
        x = 638, y = 512,
        width = 165,
        height = 77)

    canvas.create_text(
        577.5, 287.0,
        text = "Donner le nombre de variables",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    canvas.create_text(
        588.5, 409.0,
        text = "Donner le nombre de contraintes",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    entry0_img = PhotoImage(file = f"img_textBox9.png")
    entry0_bg = canvas.create_image(
        602.0, 327.5,
        image = entry0_img)

    entry0 = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entry0.place(
        x = 433, y = 311,
        width = 338,
        height = 31)

    entry1_img = PhotoImage(file = f"img_textBox10.png")
    entry1_bg = canvas.create_image(
        602.0, 445.5,
        image = entry1_img)

    entry1 = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entry1.place(
        x = 433, y = 431,
        width = 338,
        height = 27)

    canvas.create_text(
        573.5, 180.0,
        text = "Choisir un mode: 1)Max 2)Min",
        fill = "#726d72",
        font = ("Inter-Regular", int(20.0)))

    entry2_img = PhotoImage(file = f"img_textBox11.png")
    entry2_bg = canvas.create_image(
        602.0, 220.0,
        image = entry2_img)

    entry2 = Entry(
        bd = 0,
        bg = "#ffffff",
        highlightthickness = 0)

    entry2.place(
        x = 433, y = 205,
        width = 338,
        height = 28)

    canvas.create_text(
        477.5, 73.0,
        text = "Saisir un PL dans Rn",
        fill = "#bb90cf",
        font = ("Inter-Regular", int(30.0)))

    img2 = PhotoImage(file = f"img5.png")
    b2 = Button(
        image = img2,
        borderwidth = 0,
        highlightthickness = 0,
        command = retour12,
        relief = "flat")
#placement de la bouton dans la fenetre
    b2.place(
        x = 0, y = -1,
        width = 108,
        height = 74)

    f13.resizable(False, False)
    f13.mainloop()

openf1() #ouverture de f1 lors du lancement du projet
# Out:
# importing Jupyter notebook from projet4.ipynb
# ...
# <div id='ec50f7f4-fca4-4ac3-aef5-fe24b2ab247b'></div>
# importing Jupyter notebook from projet1.ipynb
# Bienvenue:
# PROJET 1:
# Notre programme permet de tracer une courbe en 3D, les lignes de niveaux, calculer le vecteur gradient et calculer la matrice Hessienne
#  ainsi que l’implémentation des méthodes de gradient à pas fixe, variable et optimal d'une fonction dans R2
# importing Jupyter notebook from projet2.ipynb
# ...
# importing Jupyter notebook from projet5.ipynb
# ...
# importing Jupyter notebook from projet6.ipynb
# ...
